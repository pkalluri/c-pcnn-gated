# %%
import random
import torch
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from termcolor import colored, cprint
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np
import torch.nn as nn

# %%
# Hyperparameters
opts = {}

# Data settings
opts['num_train_samples']=10000
opts['num_test_samples']=1000
opts['batch_size']=20
opts['num_gaussians']=2
opts['gauss_weights']=None
opts['gap']=20

# Model and learning settings
opts['hidden_layer_size']=50
opts['learning_rate']=1e-4
opts['epochs']=200

# %% [markdown]
# # Get data

# %%
def unconditional_gaussian_mixture(num_gaussians, gap, num_samples, batch_size, weights=None):    
    # Creating gaussians
    gaussians = []
    for n in range(num_gaussians):
        gauss = norm(loc=(n+1)*gap)
        gaussians.append(gauss)

    # Sampling
    data = []  # Each sample will be (x, [y, y', ...])
    num_batches = int(num_samples/batch_size) + 1
    for batch_i in range(num_batches):
        x = [1.]
        Y = []
        for sample_i in range(batch_size):
            gauss = np.random.choice(gaussians, p=weights)
            Y.append(gauss.rvs(size=1)[0])
        data.append((x, Y))    
    return gaussians, data

gaussians, train_data = unconditional_gaussian_mixture(opts['num_gaussians'], opts['gap'], opts['num_train_samples'], opts['batch_size'])
_, test_data = unconditional_gaussian_mixture(opts['num_gaussians'], opts['gap'], opts['num_test_samples'], opts['batch_size'])

# Plot Gaussians
fig, ax = plt.subplots()
plt.title('Data Histogram')
plt.axis([0, (len(gaussians)+1)*opts['gap'],0,1])
plt.ylabel('%')
x = np.arange(0, (len(gaussians)+1)*opts['gap'], 1)
for gauss in gaussians:
    ax.plot(x, gauss.pdf(x))
# Plot data
sample_Y = [y for sample in train_data for y in sample[1]]
h = ax.hist(sample_Y, density=True)

# %% [markdown]
# # Model and losses

# %%
# Define simple neural net
def get_new_model():
    model = torch.nn.Sequential(
    torch.nn.Linear(1, opts['hidden_layer_size']),
    torch.nn.ReLU(),
    torch.nn.Linear(opts['hidden_layer_size'], int(opts['hidden_layer_size'])),
    torch.nn.ReLU(),
    torch.nn.Linear(int(opts['hidden_layer_size']), int(opts['hidden_layer_size']/2)),
    torch.nn.ReLU(),
    torch.nn.Linear(int(opts['hidden_layer_size']/2), 1),
    )
    return model

# %%
# Write and loss,or loss
class StandardLossDefiner(torch.nn.Module):
    def __init__(self):
        super(StandardLossDefiner, self).__init__()
        self.loss_function = nn.MSELoss(reduction='elementwise_mean')

    def forward(self, pred, targets):
        return self.loss_function(pred.expand(opts['batch_size']),targets) # avg in log space (all y)

    
class SumLossDefiner(torch.nn.Module):
    def __init__(self):
        super(SumLossDefiner, self).__init__()
        self.loss_function = nn.MSELoss(reduction='none')

    def forward(self, pred, targets):
        losses = self.loss_function(pred.expand(opts['batch_size']),targets)
        Y_loss = torch.logsumexp(losses, dim=0)/opts['batch_size'] # avg in non log-space (any y in Y)
        return Y_loss
    
class MaxLossDefiner(torch.nn.Module):
    def __init__(self):
        super(MaxLossDefiner, self).__init__()
        self.loss_function = nn.MSELoss(reduction='none')

    def forward(self, pred, targets):
        losses = self.loss_function(pred.expand(opts['batch_size']),targets)
        Y_loss = torch.min(losses, dim=0)[0] # min (any y in Y)
        return Y_loss
    
standard_criterion = StandardLossDefiner()
sum_criterion = SumLossDefiner()
max_criterion = MaxLossDefiner()

# %% [markdown]
# # Train and test

# %%
def prep(li):
    return torch.FloatTensor(li) # e.g. x=[1.]

print('sample:',prep(train_data[0][0]))
# Out:
# sample: tensor([1.])

# %%
def train_and_test(criterion):
    optimizer = torch.optim.Adam(model.parameters(), lr=opts['learning_rate'])
    for epoch in range(opts['epochs']):
        # Train
        epoch_loss=0.0
        for (x,Y) in train_data:
            # Forward pass: compute predicted y
            pred = model(prep(x))
            loss = criterion(pred, prep(Y))
            # Backward pass: compute gradient of the loss with respect to model
            optimizer.zero_grad()
            loss.backward() 
            optimizer.step()
            # Stats
            epoch_loss += loss.item()
        
        if epoch%5 == 0:
            # Predict
            predictions = []
            for (x,Y) in test_data:
                prediction = model(prep(x)).item()
                predictions.append(prediction)
            
            # Report
            print('Epoch %d loss:%.3f predicts(mean):%f' % (epoch, epoch_loss, sum(predictions)/len(predictions)))
            fig, ax = plt.subplots()
            plt.title('Epoch %d predictions' % (epoch))
            plt.ylabel('%')
            plt.axis([0, (len(gaussians)+1)*opts['gap'], 0, 1])
            # Plot Gaussians
            x = np.arange(0, (opts['num_gaussians']+1)*opts['gap'], .1)
            for gauss in gaussians:
                ax.plot(x, gauss.pdf(x))
            # Plot predictions
            h = ax.hist(predictions, density=True)
            
    return

# %%
model = get_new_model()

# %%
train_and_test(max_criterion)
# Out:
# Epoch 0 loss:147460.187 predicts(mean):4.293776
# Epoch 5 loss:17.726 predicts(mean):20.064949
# Epoch 10 loss:14.730 predicts(mean):19.985298
# Epoch 15 loss:16.731 predicts(mean):19.542980
# Epoch 20 loss:18.848 predicts(mean):19.517887
# Epoch 25 loss:18.848 predicts(mean):19.517878
# Epoch 30 loss:18.848 predicts(mean):19.517883
# Epoch 35 loss:18.848 predicts(mean):19.517891
# Epoch 40 loss:18.848 predicts(mean):19.517899
# Epoch 45 loss:18.848 predicts(mean):19.517906
# Epoch 50 loss:18.848 predicts(mean):19.517916
# Epoch 55 loss:18.848 predicts(mean):19.517925
# Epoch 60 loss:18.848 predicts(mean):19.517935
# Epoch 65 loss:18.848 predicts(mean):19.517944
# Epoch 70 loss:18.848 predicts(mean):19.517954
# Epoch 75 loss:18.848 predicts(mean):19.517958
# Epoch 80 loss:18.848 predicts(mean):19.517969
# Epoch 85 loss:18.848 predicts(mean):19.517977
# Epoch 90 loss:18.848 predicts(mean):19.517988
# Epoch 95 loss:18.848 predicts(mean):19.517994
# Epoch 100 loss:18.848 predicts(mean):19.518003
# /Users/pkalluri/env/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 105 loss:18.848 predicts(mean):19.518204
# Epoch 110 loss:16.772 predicts(mean):19.515875
# Epoch 115 loss:16.772 predicts(mean):19.516010
# Epoch 120 loss:18.847 predicts(mean):19.516972
# Epoch 125 loss:18.848 predicts(mean):19.517624
# Epoch 130 loss:18.848 predicts(mean):19.518017
# Epoch 135 loss:16.772 predicts(mean):19.515894
# Epoch 140 loss:18.847 predicts(mean):19.516994
# Epoch 145 loss:18.848 predicts(mean):19.517653
# Epoch 150 loss:18.848 predicts(mean):19.518053
# Epoch 155 loss:16.772 predicts(mean):19.515930
# Epoch 160 loss:18.847 predicts(mean):19.517027
# Epoch 165 loss:18.848 predicts(mean):19.517683
# Epoch 170 loss:18.848 predicts(mean):19.518085
# Epoch 175 loss:16.772 predicts(mean):19.515963
# Epoch 180 loss:18.847 predicts(mean):19.517061
# Epoch 185 loss:18.848 predicts(mean):19.517721
# Epoch 190 loss:18.848 predicts(mean):19.518122
# Epoch 195 loss:16.772 predicts(mean):19.515995

# %%
model = get_new_model()

# %%
train_and_test(standard_criterion)
# Out:
# Epoch 0 loss:488012.828 predicts(mean):1.673671
# Epoch 5 loss:50642.262 predicts(mean):30.107584
# Epoch 10 loss:50651.689 predicts(mean):30.158028
# Epoch 15 loss:50653.166 predicts(mean):30.165798
# Epoch 20 loss:50653.295 predicts(mean):30.166479
# Epoch 25 loss:50653.304 predicts(mean):30.166527
# Epoch 30 loss:50653.304 predicts(mean):30.166525
# Epoch 35 loss:50653.303 predicts(mean):30.166523
# Epoch 40 loss:50653.302 predicts(mean):30.166515
# Epoch 45 loss:50653.302 predicts(mean):30.166510
# Epoch 50 loss:50653.301 predicts(mean):30.166500
# Epoch 55 loss:50653.300 predicts(mean):30.166496
# Epoch 60 loss:50653.299 predicts(mean):30.166492
# Epoch 65 loss:50653.298 predicts(mean):30.166487
# Epoch 70 loss:50653.298 predicts(mean):30.166481
# Epoch 75 loss:50653.297 predicts(mean):30.166477
# Epoch 80 loss:50653.296 predicts(mean):30.166470
# Epoch 85 loss:50653.296 predicts(mean):30.166462
# Epoch 90 loss:50653.295 predicts(mean):30.166456
# Epoch 95 loss:50653.294 predicts(mean):30.166452
# Epoch 100 loss:50653.293 predicts(mean):30.166445
# /Users/pkalluri/env/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 105 loss:50653.292 predicts(mean):30.166441
# Epoch 110 loss:50653.292 predicts(mean):30.166433
# Epoch 115 loss:50653.291 predicts(mean):30.166430
# Epoch 120 loss:50653.290 predicts(mean):30.166424
# Epoch 125 loss:50653.289 predicts(mean):30.166418
# Epoch 130 loss:50653.288 predicts(mean):30.166409
# Epoch 135 loss:50653.288 predicts(mean):30.166404
# Epoch 140 loss:50653.287 predicts(mean):30.166399
# Epoch 145 loss:50653.286 predicts(mean):30.166391
# Epoch 150 loss:50653.285 predicts(mean):30.166389
# Epoch 155 loss:50653.285 predicts(mean):30.166382
# Epoch 160 loss:50653.284 predicts(mean):30.166376
# Epoch 165 loss:50653.283 predicts(mean):30.166368
# Epoch 170 loss:50653.282 predicts(mean):30.166365
# Epoch 175 loss:50653.281 predicts(mean):30.166359
# Epoch 180 loss:50653.281 predicts(mean):30.166351
# Epoch 185 loss:50653.280 predicts(mean):30.166344
# Epoch 190 loss:50653.279 predicts(mean):30.166338
# Epoch 195 loss:50653.278 predicts(mean):30.166330

# %%
model = get_new_model()

# %%
train_and_test(sum_criterion)
# Out:
# Epoch 0 loss:38884.267 predicts(mean):7.222243
# Epoch 5 loss:3542.195 predicts(mean):30.002878
# Epoch 10 loss:3542.233 predicts(mean):30.002371
# Epoch 15 loss:3542.235 predicts(mean):30.002348
# Epoch 20 loss:3542.235 predicts(mean):30.002359
# Epoch 25 loss:3542.234 predicts(mean):30.002382
# Epoch 30 loss:3542.233 predicts(mean):30.002401
# Epoch 35 loss:3542.231 predicts(mean):30.002420
# Epoch 40 loss:3542.230 predicts(mean):30.002438
# Epoch 45 loss:3542.229 predicts(mean):30.002459
# Epoch 50 loss:3542.228 predicts(mean):30.002478
# Epoch 55 loss:3542.227 predicts(mean):30.002493
# Epoch 60 loss:3542.226 predicts(mean):30.002516
# Epoch 65 loss:3542.225 predicts(mean):30.002535
# Epoch 70 loss:3542.224 predicts(mean):30.002556
# Epoch 75 loss:3542.223 predicts(mean):30.002579
# Epoch 80 loss:3542.222 predicts(mean):30.002592
# Epoch 85 loss:3542.220 predicts(mean):30.002613
# Epoch 90 loss:3542.219 predicts(mean):30.002636
# Epoch 95 loss:3542.218 predicts(mean):30.002653
# Epoch 100 loss:3542.217 predicts(mean):30.002676
# /Users/pkalluri/env/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Epoch 105 loss:3542.216 predicts(mean):30.002693
# Epoch 110 loss:3542.215 predicts(mean):30.002708
# Epoch 115 loss:3542.214 predicts(mean):30.002735
# Epoch 120 loss:3542.213 predicts(mean):30.002754
# Epoch 125 loss:3542.211 predicts(mean):30.002773
# Epoch 130 loss:3542.210 predicts(mean):30.002790
# Epoch 135 loss:3542.209 predicts(mean):30.002817
# Epoch 140 loss:3542.208 predicts(mean):30.002832
# Epoch 145 loss:3542.207 predicts(mean):30.002851
# Epoch 150 loss:3542.206 predicts(mean):30.002872
# Epoch 155 loss:3542.205 predicts(mean):30.002901
# Epoch 160 loss:3542.203 predicts(mean):30.002920
# Epoch 165 loss:3542.202 predicts(mean):30.002941
# Epoch 170 loss:3542.201 predicts(mean):30.002958
# Epoch 175 loss:3542.199 predicts(mean):30.002979
# Epoch 180 loss:3542.198 predicts(mean):30.002996
# Epoch 185 loss:3542.197 predicts(mean):30.003021
# Epoch 190 loss:3542.196 predicts(mean):30.003042
# Epoch 195 loss:3542.195 predicts(mean):30.003063
